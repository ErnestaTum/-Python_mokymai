# %%
import pandas as pd

# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (8.0.28)
# Requirement already satisfied: protobuf>=3.0.0 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from mysql-connector-python) (3.19.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\arunas\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (1.4.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (1.1.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\arunas\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import mysql.connector 
import json


with open("credentials.json", "r") as fr:
    credentials = json.load(fr)

mydb = mysql.connector.connect(
    host="localhost", # IP address
    port="3317",
    user= credentials["user"],
    password= credentials ["pass"]
)

cursor = mydb.cursor()
cursor.execute('USE sakila')
df = pd.read_sql('SELECT * FROM actor', con=mydb)
df
# Out:
# C:\Users\arunas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
df = pd.read_csv('wine_cleaned.csv', index_col=0)
df
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 1                                     Avidagos      87   15.0           Douro
# 2                                          NaN      87   14.0          Oregon
# 3                         Reserve Late Harvest      87   13.0        Michigan
# 4           Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                                 Ars In Vitro      87   15.0  Northern Spain
# ...                                        ...     ...    ...             ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0           Mosel
# 129967                                     NaN      90   75.0          Oregon
# 129968                                   Kritt      90   30.0          Alsace
# 129969                                     NaN      90   32.0          Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0          Alsace
#
#                    region_1           region_2         taster_name  \
# 1                       NaN                NaN          Roger Voss
# 2         Willamette Valley  Willamette Valley        Paul Gregutt
# 3       Lake Michigan Shore                NaN  Alexander Peartree
# 4         Willamette Valley  Willamette Valley        Paul Gregutt
# 5                   Navarra                NaN   Michael Schachner
# ...                     ...                ...                 ...
# 129966                  NaN                NaN  Anna Lee C. Iijima
# 129967               Oregon       Oregon Other        Paul Gregutt
# 129968               Alsace                NaN          Roger Voss
# 129969               Alsace                NaN          Roger Voss
# 129970               Alsace                NaN          Roger Voss
#
#        taster_twitter_handle  \
# 1                 @vossroger
# 2                @paulgwine
# 3                        NaN
# 4                @paulgwine
# 5                @wineschach
# ...                      ...
# 129966                   NaN
# 129967           @paulgwine
# 129968            @vossroger
# 129969            @vossroger
# 129970            @vossroger
#
#                                                     title             variety  \
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# ...                                                   ...                 ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...            Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                                           winery  naujas_stulpelis  \
# 1                            Quinta dos Avidagos             13.05
# 2                                      Rainstorm             12.18
# 3                                     St. Julian             11.31
# 4                                   Sweet Cheeks             56.55
# 5                                         Tandem             13.05
# ...                                          ...               ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)             25.20
# 129967                                  Citation             67.50
# 129968                           Domaine Gresser             27.00
# 129969                      Domaine Marcel Deiss             28.80
# 129970                          Domaine Schoffit             18.90
#
#         description_length  description_world                 place
# 1                      227                 38        Portugal Douro
# 2                      186                 28             US Oregon
# 3                      199                 33           US Michigan
# 4                      249                 41             US Oregon
# 5                      261                 42  Spain Northern Spain
# ...                    ...                ...                   ...
# 129966                 227                 34         Germany Mosel
# 129967                 233                 38             US Oregon
# 129968                 225                 43         France Alsace
# 129969                 216                 40         France Alsace
# 129970                 169                 27         France Alsace
#
# [111538 rows x 17 columns]

# %%
df.head(3)
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
#
#             designation  points  price  province             region_1  \
# 1              Avidagos      87   15.0     Douro                  NaN
# 2                   NaN      87   14.0    Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0  Michigan  Lake Michigan Shore
#
#             region_2         taster_name taster_twitter_handle  \
# 1                NaN          Roger Voss            @vossroger
# 2  Willamette Valley        Paul Gregutt           @paulgwine
# 3                NaN  Alexander Peartree                   NaN
#
#                                                title         variety  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
#
#                 winery  naujas_stulpelis  description_length  \
# 1  Quinta dos Avidagos             13.05                 227
# 2            Rainstorm             12.18                 186
# 3           St. Julian             11.31                 199
#
#    description_world           place
# 1                 38  Portugal Douro
# 2                 28       US Oregon
# 3                 33     US Michigan

# %%
df.rename (index = {1: "first", 2:"second"})
# Out:
#          country                                        description  \
# first   Portugal  This is ripe and fruity, a wine that is smooth...
# second        US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# first                                 Avidagos      87   15.0           Douro
# second                                     NaN      87   14.0          Oregon
# 3                         Reserve Late Harvest      87   13.0        Michigan
# 4           Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                                 Ars In Vitro      87   15.0  Northern Spain
# ...                                        ...     ...    ...             ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0           Mosel
# 129967                                     NaN      90   75.0          Oregon
# 129968                                   Kritt      90   30.0          Alsace
# 129969                                     NaN      90   32.0          Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0          Alsace
#
#                    region_1           region_2         taster_name  \
# first                   NaN                NaN          Roger Voss
# second    Willamette Valley  Willamette Valley        Paul Gregutt
# 3       Lake Michigan Shore                NaN  Alexander Peartree
# 4         Willamette Valley  Willamette Valley        Paul Gregutt
# 5                   Navarra                NaN   Michael Schachner
# ...                     ...                ...                 ...
# 129966                  NaN                NaN  Anna Lee C. Iijima
# 129967               Oregon       Oregon Other        Paul Gregutt
# 129968               Alsace                NaN          Roger Voss
# 129969               Alsace                NaN          Roger Voss
# 129970               Alsace                NaN          Roger Voss
#
#        taster_twitter_handle  \
# first             @vossroger
# second           @paulgwine
# 3                        NaN
# 4                @paulgwine
# 5                @wineschach
# ...                      ...
# 129966                   NaN
# 129967           @paulgwine
# 129968            @vossroger
# 129969            @vossroger
# 129970            @vossroger
#
#                                                     title             variety  \
# first       Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# second      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# ...                                                   ...                 ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...            Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                                           winery  naujas_stulpelis  \
# first                        Quinta dos Avidagos             13.05
# second                                 Rainstorm             12.18
# 3                                     St. Julian             11.31
# 4                                   Sweet Cheeks             56.55
# 5                                         Tandem             13.05
# ...                                          ...               ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)             25.20
# 129967                                  Citation             67.50
# 129968                           Domaine Gresser             27.00
# 129969                      Domaine Marcel Deiss             28.80
# 129970                          Domaine Schoffit             18.90
#
#         description_length  description_world                 place
# first                  227                 38        Portugal Douro
# second                 186                 28             US Oregon
# 3                      199                 33           US Michigan
# 4                      249                 41             US Oregon
# 5                      261                 42  Spain Northern Spain
# ...                    ...                ...                   ...
# 129966                 227                 34         Germany Mosel
# 129967                 233                 38             US Oregon
# 129968                 225                 43         France Alsace
# 129969                 216                 40         France Alsace
# 129970                 169                 27         France Alsace
#
# [111538 rows x 17 columns]

# %%
df=df.rename(columns = {"taster_name": "Tester"}) #rename

# %%
df.head(3)
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
#
#             designation  points  price  province             region_1  \
# 1              Avidagos      87   15.0     Douro                  NaN
# 2                   NaN      87   14.0    Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0  Michigan  Lake Michigan Shore
#
#             region_2              Tester taster_twitter_handle  \
# 1                NaN          Roger Voss            @vossroger
# 2  Willamette Valley        Paul Gregutt           @paulgwine
# 3                NaN  Alexander Peartree                   NaN
#
#                                                title         variety  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
#
#                 winery  naujas_stulpelis  description_length  \
# 1  Quinta dos Avidagos             13.05                 227
# 2            Rainstorm             12.18                 186
# 3           St. Julian             11.31                 199
#
#    description_world           place
# 1                 38  Portugal Douro
# 2                 28       US Oregon
# 3                 33     US Michigan

# %%
#dtype

df["points"].dtype
# Out:
# dtype('int64')

# %%
print(df["description"].dtype) #object yra tekstas
# Out:
# object

# %%
df["price"].dtype
# Out:
# dtype('float64')

# %%
df["points"].astype('float64')#duomenu nepakeicia lentelej
df["points"]=df["points"].astype('float64') #dabar pasikeicia
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'points'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\arunas\Documents\-Python_mokymai\paskaita_8.ipynb Cell 13' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arunas/Documents/-Python_mokymai/paskaita_8.ipynb#ch0000012?line=0'>1</a> df["points"].astype('float64')#duomenu nepakeicia lentelej
#       <a href='vscode-notebook-cell:/c%3A/Users/arunas/Documents/-Python_mokymai/paskaita_8.ipynb#ch0000012?line=1'>2</a> df["points"]=df["points"].astype('float64')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'points'

# %%
df.head(2)
# Out:
#           x  multiply_by_2   squared
# 0  0.000000       0.000000  0.000000
# 1  0.526316       1.052632  0.277008

# %%
df[df["region_2"].isna()] #kiek yra tusciu suzinom
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# 7         France  This dry and restrained wine offers spice in p...
# ...          ...                                                ...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 1                                     Avidagos      87   15.0
# 3                         Reserve Late Harvest      87   13.0
# 5                                 Ars In Vitro      87   15.0
# 6                                      Belsito      87   16.0
# 7                                          NaN      87   24.0
# ...                                        ...     ...    ...
# 129965             Seppi Landmann Vallée Noble      90   28.0
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1 region_2              Tester  \
# 1                   Douro                  NaN      NaN          Roger Voss
# 3                Michigan  Lake Michigan Shore      NaN  Alexander Peartree
# 5          Northern Spain              Navarra      NaN   Michael Schachner
# 6       Sicily & Sardinia             Vittoria      NaN       Kerin O’Keefe
# 7                  Alsace               Alsace      NaN          Roger Voss
# ...                   ...                  ...      ...                 ...
# 129965             Alsace               Alsace      NaN          Roger Voss
# 129966              Mosel                  NaN      NaN  Anna Lee C. Iijima
# 129968             Alsace               Alsace      NaN          Roger Voss
# 129969             Alsace               Alsace      NaN          Roger Voss
# 129970             Alsace               Alsace      NaN          Roger Voss
#
#        taster_twitter_handle  \
# 1                 @vossroger
# 3                        NaN
# 5                @wineschach
# 6               @kerinokeefe
# 7                 @vossroger
# ...                      ...
# 129965            @vossroger
# 129966                   NaN
# 129968            @vossroger
# 129969            @vossroger
# 129970            @vossroger
#
#                                                     title             variety  \
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# 7                   Trimbach 2012 Gewurztraminer (Alsace)      Gewürztraminer
# ...                                                   ...                 ...
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...            Riesling
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                                           winery  naujas_stulpelis  \
# 1                            Quinta dos Avidagos             13.05
# 3                                     St. Julian             11.31
# 5                                         Tandem             13.05
# 6                                Terre di Giurfo             13.92
# 7                                       Trimbach             20.88
# ...                                          ...               ...
# 129965                   Domaine Rieflé-Landmann             25.20
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)             25.20
# 129968                           Domaine Gresser             27.00
# 129969                      Domaine Marcel Deiss             28.80
# 129970                          Domaine Schoffit             18.90
#
#         description_length  description_world                    place
# 1                      227                 38           Portugal Douro
# 3                      199                 33              US Michigan
# 5                      261                 42     Spain Northern Spain
# 6                      181                 31  Italy Sicily & Sardinia
# 7                      122                 21            France Alsace
# ...                    ...                ...                      ...
# 129965                 211                 32            France Alsace
# 129966                 227                 34            Germany Mosel
# 129968                 225                 43            France Alsace
# 129969                 216                 40            France Alsace
# 129970                 169                 27            France Alsace
#
# [64970 rows x 17 columns]

# %%
df["region_2"].fillna('Not specified') #uzpildom tuscias vietas, reikia perrasyti jei norime issaugoti
# Out:
# 1             Not specified
# 2         Willamette Valley
# 3             Not specified
# 4         Willamette Valley
# 5             Not specified
#                 ...
# 129966        Not specified
# 129967         Oregon Other
# 129968        Not specified
# 129969        Not specified
# 129970        Not specified
# Name: region_2, Length: 111538, dtype: object

# %%
df["region_2"]= df["region_2"].fillna('Not specified')
#df["region_2"].fillna('Not specified', inplace = True) ta pati padaro kaip ir virsutine lygtis - gali netycia perrassyti duomenis, geriau nenaudoti


regions_2 = df['region_2'].fillna('Not specified')
regions_2
# Out:
# 1             Not specified
# 2         Willamette Valley
# 3             Not specified
# 4         Willamette Valley
# 5             Not specified
#                 ...
# 129966        Not specified
# 129967         Oregon Other
# 129968        Not specified
# 129969        Not specified
# 129970        Not specified
# Name: region_2, Length: 111538, dtype: object

# %%
df.head()
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos    87.0   15.0           Douro
# 2                                 NaN    87.0   14.0          Oregon
# 3                Reserve Late Harvest    87.0   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block    87.0   65.0          Oregon
# 5                        Ars In Vitro    87.0   15.0  Northern Spain
#
#               region_1           region_2              Tester  \
# 1                  NaN      Not specified          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore      Not specified  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra      Not specified   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  naujas_stulpelis  \
# 1      Portuguese Red  Quinta dos Avidagos             13.05
# 2          Pinot Gris            Rainstorm             12.18
# 3            Riesling           St. Julian             11.31
# 4          Pinot Noir         Sweet Cheeks             56.55
# 5  Tempranillo-Merlot               Tandem             13.05
#
#    description_length  description_world                 place
# 1                 227                 38        Portugal Douro
# 2                 186                 28             US Oregon
# 3                 199                 33           US Michigan
# 4                 249                 41             US Oregon
# 5                 261                 42  Spain Northern Spain

# %%
df["taster_twitter_handle"].replace("@vossroger", '@me')
# Out:
# 1                 @me
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
# 5         @wineschach
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968            @me
# 129969            @me
# 129970            @me
# Name: taster_twitter_handle, Length: 111538, dtype: object

# %%
#concat
ca_videos = pd.read_csv('CAvideos.csv')
print(ca_videos.shape)
ca_videos.head(2)
# Out:
# (40881, 16)
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...
# 1  STill got a lot of packages. Probably will las...

# %%
gb_videos = pd.read_csv('GBvideos.csv')
print(gb_videos.shape)
gb_videos.head(2)
# Out:
# (38916, 16)
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
# 1  3s1rvMFUweQ      17.14.11      Taylor Swift: …Ready for It? (Live) - SNL
#
#          channel_title  category_id              publish_time  \
# 0           John Lewis           26  2017-11-10T07:38:29.000Z
# 1  Saturday Night Live           24  2017-11-12T06:24:44.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  1053632  25561
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1      2294           2757  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...
# 1  Musical guest Taylor Swift performs …Ready for...

# %%
#sujungimas lenteliu
pd.concat( [gb_videos, ca_videos])
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 40876                       HOW2: How to Solve a Mystery
# 40877                   Eli Lik Lik Episode 13 Partie 01
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...
# 40879                   Trump Advisor Grovels To Trudeau
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班
#
#                     channel_title  category_id              publish_time  \
# 0                      John Lewis           26  2017-11-10T07:38:29.000Z
# 1             Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                      EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3      Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4                Cute Girl Videos           25  2017-11-13T01:45:13.000Z
# ...                           ...          ...                       ...
# 40876             Annoying Orange           24  2018-06-13T18:00:07.000Z
# 40877            Elhiwar Ettounsi           24  2018-06-13T19:01:18.000Z
# 40878              Kingdom Hearts           20  2018-06-11T17:30:53.000Z
# 40879             The Young Turks           25  2018-06-13T04:00:05.000Z
# 40880                    我愛小明星大跟班           24  2018-06-13T16:00:03.000Z
#
#                                                     tags     views   likes  \
# 0      christmas|"john lewis christmas"|"john lewis"|...   7224515   55681
# 1      SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632   25561
# 2      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787420
# 3      Salford City FC|"Salford City"|"Salford"|"Clas...     27833     193
# 4                                                 [none]      9815      30
# ...                                                  ...       ...     ...
# 40876  annoying orange|"funny"|"fruit"|"talking"|"ani...     80685    1701
# 40877  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...    103339     460
# 40878  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...    773347   25900
# 40879  180612__TB02SorryExcuse|"News"|"Politics"|"The...    115225    2115
# 40880  吳宗憲|"吳姍儒"|"小明星大跟班"|"Sandy"|"Jacky wu"|"憲哥"|"中天...    107392     300
#
#        dislikes  comment_count  \
# 0         10247           9479
# 1          2294           2757
# 2         43420         125882
# 3            12             37
# 4             2             30
# ...         ...            ...
# 40876        99           1312
# 40877        66             51
# 40878       224           3881
# 40879       182           1672
# 40880        62            251
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg              False
# 1      https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg              False
# 2      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg              False
# 3      https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg              False
# 4      https://i.ytimg.com/vi/rHwDegptbI4/default.jpg              False
# ...                                               ...                ...
# 40876  https://i.ytimg.com/vi/sGolxsMSGfQ/default.jpg              False
# 40877  https://i.ytimg.com/vi/8HNuRNi8t70/default.jpg              False
# 40878  https://i.ytimg.com/vi/GWlKEM3m2EE/default.jpg              False
# 40879  https://i.ytimg.com/vi/lbMKLzQ4cNQ/default.jpg              False
# 40880  https://i.ytimg.com/vi/POTgw38-m58/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40876             False                   False
# 40877             False                   False
# 40878             False                   False
# 40879             False                   False
# 40880             False                   False
#
#                                              description
# 0      Click here to continue the story and make your...
# 1      Musical guest Taylor Swift performs …Ready for...
# 2      Eminem's new track Walk on Water ft. Beyoncé i...
# 3      Salford drew 4-4 against the Class of 92 and F...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 40876  🚨 NEW MERCH! http://amzn.to/annoyingorange 🚨➤ ...
# 40877  ► Retrouvez vos programmes préférés : https://...
# 40878  Find out more about Kingdom Hearts 3: https://...
# 40879  Peter Navarro isn’t talking so tough now. Ana ...
# 40880  藝人：李妍瑾、玉兔、班傑、LaLa、小優、少少專家：陳筱屏(律師)、Wendy(心理師)、羅...
#
# [79797 rows x 16 columns]

# %%
# join

ca_videos.join( gb_videos, lsuffix = '_left', rsuffix = '_right')
# Out:
#       video_id_left trending_date_left  \
# 0       n1WpP7iowLc           17.14.11
# 1       0dBIkQ4Mz1M           17.14.11
# 2       5qpjK5DgCt4           17.14.11
# 3       d380meD0W0M           17.14.11
# 4       2Vv-BfVoq4g           17.14.11
# ...             ...                ...
# 40876   sGolxsMSGfQ           18.14.06
# 40877   8HNuRNi8t70           18.14.06
# 40878   GWlKEM3m2EE           18.14.06
# 40879   lbMKLzQ4cNQ           18.14.06
# 40880   POTgw38-m58           18.14.06
#
#                                               title_left channel_title_left  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé         EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail          iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...       Rudy Mancuso
# 3                               I Dare You: GOING BALD!?           nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)         Ed Sheeran
# ...                                                  ...                ...
# 40876                       HOW2: How to Solve a Mystery    Annoying Orange
# 40877                   Eli Lik Lik Episode 13 Partie 01   Elhiwar Ettounsi
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...     Kingdom Hearts
# 40879                   Trump Advisor Grovels To Trudeau    The Young Turks
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班           我愛小明星大跟班
#
#        category_id_left         publish_time_left  \
# 0                    10  2017-11-10T17:00:03.000Z
# 1                    23  2017-11-13T17:00:00.000Z
# 2                    23  2017-11-12T19:05:24.000Z
# 3                    24  2017-11-12T18:01:41.000Z
# 4                    10  2017-11-09T11:04:14.000Z
# ...                 ...                       ...
# 40876                24  2018-06-13T18:00:07.000Z
# 40877                24  2018-06-13T19:01:18.000Z
# 40878                20  2018-06-11T17:30:53.000Z
# 40879                25  2018-06-13T04:00:05.000Z
# 40880                24  2018-06-13T16:00:03.000Z
#
#                                                tags_left  views_left  \
# 0      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...    17158579
# 1      plush|"bad unboxing"|"unboxing"|"fan mail"|"id...     1014651
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...     3191434
# 3      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...     2095828
# 4      edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...    33523622
# ...                                                  ...         ...
# 40876  annoying orange|"funny"|"fruit"|"talking"|"ani...       80685
# 40877  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...      103339
# 40878  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...      773347
# 40879  180612__TB02SorryExcuse|"News"|"Politics"|"The...      115225
# 40880  吳宗憲|"吳姍儒"|"小明星大跟班"|"Sandy"|"Jacky wu"|"憲哥"|"中天...      107392
#
#        likes_left  dislikes_left  ...  \
# 0          787425          43420  ...
# 1          127794           1688  ...
# 2          146035           5339  ...
# 3          132239           1989  ...
# 4         1634130          21082  ...
# ...           ...            ...  ...
# 40876        1701             99  ...
# 40877         460             66  ...
# 40878       25900            224  ...
# 40879        2115            182  ...
# 40880         300             62  ...
#
#                                               tags_right views_right  \
# 0      christmas|"john lewis christmas"|"john lewis"|...   7224515.0
# 1      SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632.0
# 2      Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579.0
# 3      Salford City FC|"Salford City"|"Salford"|"Clas...     27833.0
# 4                                                 [none]      9815.0
# ...                                                  ...         ...
# 40876                                                NaN         NaN
# 40877                                                NaN         NaN
# 40878                                                NaN         NaN
# 40879                                                NaN         NaN
# 40880                                                NaN         NaN
#
#        likes_right  dislikes_right  comment_count_right  \
# 0          55681.0         10247.0               9479.0
# 1          25561.0          2294.0               2757.0
# 2         787420.0         43420.0             125882.0
# 3            193.0            12.0                 37.0
# 4             30.0             2.0                 30.0
# ...            ...             ...                  ...
# 40876          NaN             NaN                  NaN
# 40877          NaN             NaN                  NaN
# 40878          NaN             NaN                  NaN
# 40879          NaN             NaN                  NaN
# 40880          NaN             NaN                  NaN
#
#                                  thumbnail_link_right comments_disabled_right  \
# 0      https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg                   False
# 1      https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg                   False
# 2      https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg                   False
# 3      https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg                   False
# 4      https://i.ytimg.com/vi/rHwDegptbI4/default.jpg                   False
# ...                                               ...                     ...
# 40876                                             NaN                     NaN
# 40877                                             NaN                     NaN
# 40878                                             NaN                     NaN
# 40879                                             NaN                     NaN
# 40880                                             NaN                     NaN
#
#       ratings_disabled_right video_error_or_removed_right  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
# ...                      ...                          ...
# 40876                    NaN                          NaN
# 40877                    NaN                          NaN
# 40878                    NaN                          NaN
# 40879                    NaN                          NaN
# 40880                    NaN                          NaN
#
#                                        description_right
# 0      Click here to continue the story and make your...
# 1      Musical guest Taylor Swift performs …Ready for...
# 2      Eminem's new track Walk on Water ft. Beyoncé i...
# 3      Salford drew 4-4 against the Class of 92 and F...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 40876                                                NaN
# 40877                                                NaN
# 40878                                                NaN
# 40879                                                NaN
# 40880                                                NaN
#
# [40881 rows x 32 columns]

# %%
df_1 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5'],
                   'B': ['B0', 'B1', 'B2', 'B3', 'B4', 'B5']})
df_1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3
# 4  K4  A4  B4
# 5  K5  A5  B5

# %%
df_2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', ],
                   'C': ['C0', 'C1', 'C2'],
                   'B': ['B0', 'B1', 'B2']})

df_2
# Out:
#   key   C   B
# 0  K0  C0  B0
# 1  K1  C1  B1
# 2  K2  C2  B2

# %%
df_1.join(df_2, lsuffix = '_l', rsuffix = '_r')
# Out:
#   key_l   A B_l key_r    C  B_r
# 0    K0  A0  B0    K0   C0   B0
# 1    K1  A1  B1    K1   C1   B1
# 2    K2  A2  B2    K2   C2   B2
# 3    K3  A3  B3   NaN  NaN  NaN
# 4    K4  A4  B4   NaN  NaN  NaN
# 5    K5  A5  B5   NaN  NaN  NaN

# %%
df_1.join(df_2.set_index('key'), on='key', lsuffix='_l', rsuffix='_r') # sujungiam per index k
# Out:
#   key   A B_l    C  B_r
# 0  K0  A0  B0   C0   B0
# 1  K1  A1  B1   C1   B1
# 2  K2  A2  B2   C2   B2
# 3  K3  A3  B3  NaN  NaN
# 4  K4  A4  B4  NaN  NaN
# 5  K5  A5  B5  NaN  NaN

# %%
df_1.join(df_2.set_index('key'), on='key', how='inner', lsuffix='_l', rsuffix='_r') #palieka tik kur abu reikmes turi
# Out:
#   key   A B_l   C B_r
# 0  K0  A0  B0  C0  B0
# 1  K1  A1  B1  C1  B1
# 2  K2  A2  B2  C2  B2

# %%
#merge - ta pati kaip ir join, tik join - left dazniausiai, o merge - inner join

df_1.merge(df_2, on='key', how='left', suffixes=('_left', '_right' ) )
# Out:
#   key   A B_left    C B_right
# 0  K0  A0     B0   C0      B0
# 1  K1  A1     B1   C1      B1
# 2  K2  A2     B2   C2      B2
# 3  K3  A3     B3  NaN     NaN
# 4  K4  A4     B4  NaN     NaN
# 5  K5  A5     B5  NaN     NaN

# %%
df_1.merge(df_2, on='key', suffixes=('_left', '_right' ) )
# Out:
#   key   A B_left   C B_right
# 0  K0  A0     B0  C0      B0
# 1  K1  A1     B1  C1      B1
# 2  K2  A2     B2  C2      B2

# %%
#multilIndex

ca_videos.head(2)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...
# 1  STill got a lot of packages. Probably will las...

# %%
grouped = ca_videos.groupby(['channel_title', "comments_disabled"]).sum()
grouped
# Out:
#                                          category_id     views   likes  \
# channel_title         comments_disabled
# #AndresSTyle          False                       66   1330191   16384
# #Mind Warehouse       False                      918  39464664  536411
# #SeekingTheTruth      False                       25    119011    3277
# * Martyna *           False                       72     44973     524
# - 欢迎订阅 -浙江卫视【奔跑吧】官方频道 False                      864  48769105  345378
# ...                                              ...       ...     ...
# 창조영감클럽                False                       22     75953     307
# 타우TV                  False                       28    471919    4160
# 포스트쉐어                 False                       24   1658045    5150
# 포크포크                  False                       27    605936    6058
# 활력소TV                 False                       24    820790    1157
#
#                                          dislikes  comment_count  \
# channel_title         comments_disabled
# #AndresSTyle          False                   468           1865
# #Mind Warehouse       False                 94787         336485
# #SeekingTheTruth      False                   176           1066
# * Martyna *           False                    13            263
# - 欢迎订阅 -浙江卫视【奔跑吧】官方频道 False                 38594         125125
# ...                                           ...            ...
# 창조영감클럽                False                    60             64
# 타우TV                  False                   222           1000
# 포스트쉐어                 False                   611           2003
# 포크포크                  False                   207           1208
# 활력소TV                 False                   511            735
#
#                                          ratings_disabled  \
# channel_title         comments_disabled
# #AndresSTyle          False                             0
# #Mind Warehouse       False                             0
# #SeekingTheTruth      False                             0
# * Martyna *           False                             0
# - 欢迎订阅 -浙江卫视【奔跑吧】官方频道 False                             0
# ...                                                   ...
# 창조영감클럽                False                             0
# 타우TV                  False                             0
# 포스트쉐어                 False                             0
# 포크포크                  False                             0
# 활력소TV                 False                             0
#
#                                          video_error_or_removed
# channel_title         comments_disabled
# #AndresSTyle          False                                   0
# #Mind Warehouse       False                                   0
# #SeekingTheTruth      False                                   0
# * Martyna *           False                                   0
# - 欢迎订阅 -浙江卫视【奔跑吧】官方频道 False                                   0
# ...                                                         ...
# 창조영감클럽                False                                   0
# 타우TV                  False                                   0
# 포스트쉐어                 False                                   0
# 포크포크                  False                                   0
# 활력소TV                 False                                   0
#
# [5121 rows x 7 columns]

# %%
grouped.loc[ ( slice(None) , True ), : ] #[  ( index_1 value, index_2 value), columns] slice(None) - visi duomenys index1
# Out:
#                                                             category_id  \
# channel_title                            comments_disabled
# 24 Oras Daily                            True                        22
# 4given4ever1                             True                        50
# 5 News                                   True                        75
# AAJ NEWS WALA HINDI PUNJABI              True                        25
# ABC News (Australia)                     True                       175
# ...                                                                 ...
# ポケモン公式YouTubeチャンネル                       True                         3
# 优优独播剧场——YoYo Television Series Exclusive True                         2
# 日清食品グループ公式チャンネル                          True                        72
# 郭文贵                                      True                        50
# 뭉구                                       True                        25
#
#                                                                views   likes  \
# channel_title                            comments_disabled
# 24 Oras Daily                            True                 116229     378
# 4given4ever1                             True                 426928   13976
# 5 News                                   True                 362795       0
# AAJ NEWS WALA HINDI PUNJABI              True                  77495     200
# ABC News (Australia)                     True               21841678  130063
# ...                                                              ...     ...
# ポケモン公式YouTubeチャンネル                       True                1548760       0
# 优优独播剧场——YoYo Television Series Exclusive True                  23617      47
# 日清食品グループ公式チャンネル                          True                2105781       0
# 郭文贵                                      True                 284214    5131
# 뭉구                                       True                 947578    6800
#
#                                                             dislikes  \
# channel_title                            comments_disabled
# 24 Oras Daily                            True                    100
# 4given4ever1                             True                   1028
# 5 News                                   True                      0
# AAJ NEWS WALA HINDI PUNJABI              True                     65
# ABC News (Australia)                     True                   9684
# ...                                                              ...
# ポケモン公式YouTubeチャンネル                       True                      0
# 优优独播剧场——YoYo Television Series Exclusive True                     12
# 日清食品グループ公式チャンネル                          True                      0
# 郭文贵                                      True                   2948
# 뭉구                                       True                   1281
#
#                                                             comment_count  \
# channel_title                            comments_disabled
# 24 Oras Daily                            True                           0
# 4given4ever1                             True                           0
# 5 News                                   True                           0
# AAJ NEWS WALA HINDI PUNJABI              True                           0
# ABC News (Australia)                     True                           0
# ...                                                                   ...
# ポケモン公式YouTubeチャンネル                       True                           0
# 优优独播剧场——YoYo Television Series Exclusive True                           0
# 日清食品グループ公式チャンネル                          True                           0
# 郭文贵                                      True                           0
# 뭉구                                       True                           0
#
#                                                             ratings_disabled  \
# channel_title                            comments_disabled
# 24 Oras Daily                            True                              0
# 4given4ever1                             True                              0
# 5 News                                   True                              3
# AAJ NEWS WALA HINDI PUNJABI              True                              0
# ABC News (Australia)                     True                              0
# ...                                                                      ...
# ポケモン公式YouTubeチャンネル                       True                              3
# 优优独播剧场——YoYo Television Series Exclusive True                              0
# 日清食品グループ公式チャンネル                          True                              3
# 郭文贵                                      True                              0
# 뭉구                                       True                              0
#
#                                                             video_error_or_removed
# channel_title                            comments_disabled
# 24 Oras Daily                            True                                    0
# 4given4ever1                             True                                    0
# 5 News                                   True                                    0
# AAJ NEWS WALA HINDI PUNJABI              True                                    0
# ABC News (Australia)                     True                                    0
# ...                                                                            ...
# ポケモン公式YouTubeチャンネル                       True                                    0
# 优优独播剧场——YoYo Television Series Exclusive True                                    0
# 日清食品グループ公式チャンネル                          True                                    0
# 郭文贵                                      True                                    0
# 뭉구                                       True                                    0
#
# [118 rows x 7 columns]

# %%
grouped.loc[ ( "ABC News (Australia)" , True ):, : ] #[  (  nuo ABC kanalu, kur reikmes True, ir tada viska iki galo
# Out:
#                                            category_id     views   likes  \
# channel_title           comments_disabled
# ABC News (Australia)    True                       175  21841678  130063
# ABC Television Network  False                      192   6839748   33611
# ABC Television Stations False                      154  44810587  217938
# ABC7                    False                      100   2717653   70057
# ABIZ ENT BUZZ           False                       24    251944    3985
# ...                                                ...       ...     ...
# 창조영감클럽                  False                       22     75953     307
# 타우TV                    False                       28    471919    4160
# 포스트쉐어                   False                       24   1658045    5150
# 포크포크                    False                       27    605936    6058
# 활력소TV                   False                       24    820790    1157
#
#                                            dislikes  comment_count  \
# channel_title           comments_disabled
# ABC News (Australia)    True                   9684              0
# ABC Television Network  False                 10943           9009
# ABC Television Stations False                 36295         189031
# ABC7                    False                  3702          21842
# ABIZ ENT BUZZ           False                    57            442
# ...                                             ...            ...
# 창조영감클럽                  False                    60             64
# 타우TV                    False                   222           1000
# 포스트쉐어                   False                   611           2003
# 포크포크                    False                   207           1208
# 활력소TV                   False                   511            735
#
#                                            ratings_disabled  \
# channel_title           comments_disabled
# ABC News (Australia)    True                              0
# ABC Television Network  False                             0
# ABC Television Stations False                             0
# ABC7                    False                             0
# ABIZ ENT BUZZ           False                             0
# ...                                                     ...
# 창조영감클럽                  False                             0
# 타우TV                    False                             0
# 포스트쉐어                   False                             0
# 포크포크                    False                             0
# 활력소TV                   False                             0
#
#                                            video_error_or_removed
# channel_title           comments_disabled
# ABC News (Australia)    True                                    0
# ABC Television Network  False                                   0
# ABC Television Stations False                                   0
# ABC7                    False                                   0
# ABIZ ENT BUZZ           False                                   0
# ...                                                           ...
# 창조영감클럽                  False                                   0
# 타우TV                    False                                   0
# 포스트쉐어                   False                                   0
# 포크포크                    False                                   0
# 활력소TV                   False                                   0
#
# [5040 rows x 7 columns]

# %%
grouped.loc[ ( 'BeatFilms', True ):('Game Of Thrones', True), : ] 
#slicina nuo value iki value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\arunas\Documents\-Python_mokymai\paskaita_8.ipynb Cell 35' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arunas/Documents/-Python_mokymai/paskaita_8.ipynb#ch0000033?line=0'>1</a> grouped.loc[ ( 'BeatFilms', True ):('Game Of Thrones', True), : ]
#
# NameError: name 'grouped' is not defined

# %%
import numpy as np

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.29.1)
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\arunas\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy>=1.17 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arunas\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arunas\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\arunas\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
#plots

x = np.linspace(0,10,30)
print(x)
# Out:
# [ 0.          0.34482759  0.68965517  1.03448276  1.37931034  1.72413793
#   2.06896552  2.4137931   2.75862069  3.10344828  3.44827586  3.79310345
#   4.13793103  4.48275862  4.82758621  5.17241379  5.51724138  5.86206897
#   6.20689655  6.55172414  6.89655172  7.24137931  7.5862069   7.93103448
#   8.27586207  8.62068966  8.96551724  9.31034483  9.65517241 10.        ]

# %%
y = x*2
z = x**2

# %%
df = pd.DataFrame( [x,y,z], index = ["x", "multiply_by_2", "squared"]).T
df
# Out:
#             x  multiply_by_2     squared
# 0    0.000000       0.000000    0.000000
# 1    0.344828       0.689655    0.118906
# 2    0.689655       1.379310    0.475624
# 3    1.034483       2.068966    1.070155
# 4    1.379310       2.758621    1.902497
# 5    1.724138       3.448276    2.972652
# 6    2.068966       4.137931    4.280618
# 7    2.413793       4.827586    5.826397
# 8    2.758621       5.517241    7.609988
# 9    3.103448       6.206897    9.631391
# 10   3.448276       6.896552   11.890606
# 11   3.793103       7.586207   14.387634
# 12   4.137931       8.275862   17.122473
# 13   4.482759       8.965517   20.095125
# 14   4.827586       9.655172   23.305589
# 15   5.172414      10.344828   26.753864
# 16   5.517241      11.034483   30.439952
# 17   5.862069      11.724138   34.363853
# 18   6.206897      12.413793   38.525565
# 19   6.551724      13.103448   42.925089
# 20   6.896552      13.793103   47.562426
# 21   7.241379      14.482759   52.437574
# 22   7.586207      15.172414   57.550535
# 23   7.931034      15.862069   62.901308
# 24   8.275862      16.551724   68.489893
# 25   8.620690      17.241379   74.316290
# 26   8.965517      17.931034   80.380499
# 27   9.310345      18.620690   86.682521
# 28   9.655172      19.310345   93.222354
# 29  10.000000      20.000000  100.000000

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(title="Grafikas")
# Out:
# <AxesSubplot:title={'center':'Grafikas'}>

# %%
df.plot(title="Grafikas", kind = "bar")
# Out:
# <AxesSubplot:title={'center':'Grafikas'}>

# %%
df.plot(title='Grafikas', kind='area')
# Out:
# <AxesSubplot:title={'center':'Grafikas'}>

# %%
ax = df.plot.scatter(x="x", y="multiply_by_2", color="DarkBlue", label="Group 1")
df.plot.scatter(x="x", y="x", color="r", label="Group 2", ax=ax)
df.plot.scatter(x="x", y="squared", color="DarkGreen", label="Group 2", ax=ax)
# Out:
# <AxesSubplot:xlabel='x', ylabel='squared'>

# %%
#matplotlib
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from mpl_toolkits.mplot3d.axes3d import get_test_data


# set up a figure twice as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.5))

# =============
# First subplot
# =============
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')

# plot a 3D surface like in the example mplot3d/surface3d_demo
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=10)

# ==============
# Second subplot
# ==============
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')

# plot a 3D wireframe like in the example mplot3d/wire3d_demo
X, Y, Z = get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x)
plt.plot(y)
plt.plot(z)

# %%
fig = plt.figure()
ax = fig.add_axes(rect=[0,0,1,1])
print (type(ax))

ax.plot(x, x, label='x')
ax.plot(x, y, label='*2')
ax.plot(x, z, label='kvadratu')
ax.set_title('grafikas')
ax.set_xlabel('X asis', fontsize='xx-large', rotation=45)
ax.set_ylabel('Y asis', fontsize='xx-large', rotation=45)
ax.legend()
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
fig, axes = plt.subplots(2,3 ) #2 eiles ir 3 stulpeliai
axes [1,2]. plot(x,z)
axes [0,0]. plot(x,x)

for row in axes:
    for col_ax in row:
        col_ax.plot(x,y,c="r")

# %%
fig, axes = plt.subplots(3 )

# %%
fig, axes = plt.subplots(1, 3 )

# %%
fig = plt.figure()

ax = fig.add_axes(rect = [0,0,1,1])
ax_zoom = fig.add_axes(rect = [0.1,0.4,0.3,0.3])

print(type(ax))

ax.plot(x,x, label = 'x', c="r", ls = '--')
ax.plot(x,y, label = '2')
ax.plot(x,z, label = 'kvadratu')

ax_zoom.plot(x,x, label = 'x', c="r", ls = '--')
ax_zoom.plot(x,y, label = '2')
ax_zoom.plot(x,z, label = 'kvadratu')
ax_zoom.set_xlim( [0, 2.5])
ax_zoom.set_ylim( [0, 7])

ax_2 = fig.add_axes(rect = [1.2,0. ,1,1])
ax_3 = fig.add_axes(rect = [1.2,-1.2,1,1])

fig.savefig('mano_grafikas.png', dpi=300)
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
import pandas as pd

wine_df = pd.read_csv('winemag-data.csv', index_col=0) # relative path

# %%
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_df.plot.bar(x="taster_name", y = wine_df["taster_name"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\arunas\Documents\-Python_mokymai\paskaita_8.ipynb Cell 57' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arunas/Documents/-Python_mokymai/paskaita_8.ipynb#ch0000056?line=0'>1</a> wine_df.plot.bar(x="taster_name", y = wine_df["taster_name"].value_counts())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1131, in PlotAccessor.bar(self, x, y, **kwargs)
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1042'>1043</a> @Appender(
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1043'>1044</a>     """
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1044'>1045</a>     See Also
#    (...)
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1119'>1120</a> @Appender(_bar_or_line_doc)
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1120'>1121</a> def bar(self, x=None, y=None, **kwargs):
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1121'>1122</a>     """
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1122'>1123</a>     Vertical bar plot.
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1123'>1124</a>
#    (...)
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1128'>1129</a>     other axis represents a measured value.
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1129'>1130</a>     """
# -> <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=1130'>1131</a>     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:945, in PlotAccessor.__call__(self, *args, **kwargs)
#     <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=942'>943</a> int_y_arg = is_integer(y) or int_ylist
#     <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=943'>944</a> if int_y_arg and not data.columns.holds_integer():
# --> <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=944'>945</a>     y = data_cols[y]
#     <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=946'>947</a> label_kw = kwargs["label"] if "label" in kwargs else False
#     <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/plotting/_core.py?line=947'>948</a> for kw in ["xerr", "yerr"]:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5055, in Index.__getitem__(self, key)
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5047'>5048</a> if com.is_bool_indexer(key):
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5048'>5049</a>     # if we have list[bools, length=1e5] then doing this check+convert
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5049'>5050</a>     #  takes 166 µs + 2.1 ms and cuts the ndarray.__getitem__
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5050'>5051</a>     #  time below from 3.8 ms to 496 µs
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5051'>5052</a>     # if we already have ndarray[bool], the overhead is 1.4 µs or .25%
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5052'>5053</a>     key = np.asarray(key, dtype=bool)
# -> <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5054'>5055</a> result = getitem(key)
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5055'>5056</a> # Because we ruled out integer above, we always get an arraylike here
#    <a href='file:///c%3A/Users/arunas/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5056'>5057</a> if result.ndim > 1:
#
# IndexError: index 25514 is out of bounds for axis 0 with size 13
