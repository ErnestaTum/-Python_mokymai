# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector 
import json

# %%
with open("credentials.json", "r") as fr:
    credentials = json.load(fr)

mydb = mysql.connector.connect(
    host="localhost", 
    port="3317",
    user= credentials["user"],
    password= credentials ["pass"]
)

cursor = mydb.cursor()
cursor.execute('USE sakila')
df = pd.read_sql('SELECT * FROM anime', con=mydb)
df
# Out:
#       anime_id                                               name  \
# 0        32281                                     Kimi no Na wa.
# 1         5114                   Fullmetal Alchemist: Brotherhood
# 2        28977                                          GintamaÂ°
# 3         9253                                        Steins;Gate
# 4         9969                                      Gintama&#039;
# ...        ...                                                ...
# 1597      6572                                Shakugan no Shana S
# 1598      2585  Soukou Kihei Votoms: Red Shoulder Document - Y...
# 1599       560  Soukyuu no Fafner: Right of Left - Single Program
# 1600     23725            Strike Witches: Operation Victory Arrow
# 1601     21737  Tamayura: More Aggressive - Tsuitachi dake no ...
#
#                                                   genre     type  episodes  \
# 0                  Drama, Romance, School, Supernatural    Movie         1
# 1     Action, Adventure, Drama, Fantasy, Magic, Mili...       TV        64
# 2     Action, Comedy, Historical, Parody, Samurai, S...       TV        51
# 3                                      Sci-Fi, Thriller       TV        24
# 4     Action, Comedy, Historical, Parody, Samurai, S...       TV        51
# ...                                                 ...      ...       ...
# 1597  Action, Drama, Fantasy, Romance, School, Super...      OVA         4
# 1598                     Drama, Mecha, Military, Sci-Fi      OVA         1
# 1599             Action, Drama, Mecha, Military, Sci-Fi  Special         1
# 1600             Action, Ecchi, Magic, Military, Sci-Fi      OVA         3
# 1601                       Comedy, Drama, Slice of Life  Special         1
#
#       rating  members
# 0       9.37   200630
# 1       9.26   793665
# 2       9.25   114262
# 3       9.17   673572
# 4       9.16   151266
# ...      ...      ...
# 1597    7.49    53129
# 1598    7.49     2049
# 1599    7.49     9482
# 1600    7.49    11203
# 1601    7.49     2770
#
# [1602 rows x 7 columns]
